# %%
import numpy as np
import pandas as pd

pd.read_csv('profiling_test_results.csv', sep='\t')
# Out:
#           ID                         CORRELATIONID  MESSAGESIZE  \
# 0        442  e6831ae4-4adc-4a52-960d-5fdcd5729ca0        10000
# 1        443  a46ed04c-1269-427b-9665-d278b011181b        10000
# 2        444  aedb1991-a00a-448d-8db9-e535741a86b4        10000
# 3        445  ccdd9210-263c-4f46-930b-36a659252ea6        10000
# 4        446  df671773-9358-40b2-bf3e-c50a0dfd7b54        10000
# ...      ...                                   ...          ...
# 39473  67874  34fdce36-e7df-422e-8e49-a969bcd4751c      1000000
# 39474  67875  ec5a0a80-402d-435a-80cf-1392f1a8cab2      1000000
# 39475  67876  b227218b-b3e3-4369-8d29-5c882ee0f6b9      1000000
# 39476  65877  2cfa3252-aafc-428a-bf81-9b60b6e90b46       100000
# 39477  66877  b889cc9c-0471-4add-8957-e7be63909235      1000000
#
#        MESSAGEVOLUME  REQUESTTYPE                    SENDTIME  \
# 0                100  SPRING AMQP  2020-03-16 15:36:55.096000
# 1                100  SPRING AMQP  2020-03-16 15:36:55.229000
# ...
