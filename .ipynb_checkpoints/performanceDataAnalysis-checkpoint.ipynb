# %%
import numpy as np
import pandas as pd

profiledData = pd.read_csv('profiling_test_results.csv', sep='\t')
profiledData

#springAMQP = profiledData.query('REQUESTTYPE =="SPRING AMQP"') 
#springAMQP

#rabbitClient = profiledData.query('REQUESTTYPE =="RABBITMQ JAVA CLIENT"') 
#rabbitClient

#jeroMQ = profiledData.query('REQUESTTYPE =="JEROMQ"') 
#jeroMQ

#jzmq = profiledData.query('REQUESTTYPE =="JZMQ"') 
#jzmq
# Out:
#           ID                         CORRELATIONID  MESSAGESIZE  \
# 29578  57977  ea4f5686-95cf-4586-876b-23c25f63c892        10000
# 29579  57978  60dab3e8-84bf-4f50-b6e3-5a56b387fb36        10000
# 29580  57979  249235df-bd39-4f34-ae5c-fc6ca5d0ae5c        10000
# 29581  57980  f3668eb3-2d92-4d88-83de-319fc21fbb43        10000
# 29582  57981  1196b9cf-9fe5-4883-b596-e892d1f73618        10000
# ...      ...                                   ...          ...
# 39473  67874  34fdce36-e7df-422e-8e49-a969bcd4751c      1000000
# 39474  67875  ec5a0a80-402d-435a-80cf-1392f1a8cab2      1000000
# 39475  67876  b227218b-b3e3-4369-8d29-5c882ee0f6b9      1000000
# 39476  65877  2cfa3252-aafc-428a-bf81-9b60b6e90b46       100000
# 39477  66877  b889cc9c-0471-4add-8957-e7be63909235      1000000
#
#        MESSAGEVOLUME REQUESTTYPE                    SENDTIME  ISMULTITHREADED  \
# 29578            100      JEROMQ  2020-03-18 12:40:35.297000                1
# ...
